# %% [markdown]
# ### Import necessary libary

# %%
import numpy as np
import pandas as pd
import json
from geopy.geocoders import Nominatim
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  54.92 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  16.22 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  30.37 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  46.64 MB/s
# Libraries imported.

# %% [markdown]
# ### Scratch Neighborhood data from wiki website

# %%
from bs4 import BeautifulSoup
# !wget -q -O 'html_doc' https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
print('Data downloaded!')
with open('html_doc') as html_doc:
    soup = BeautifulSoup(html_doc)
# Out:
# Data downloaded!
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /opt/conda/envs/DSX-Python35/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# ### Parse the data that scratched from website

# %%
table = soup.tbody
data = []

table = soup.find('table', attrs={'class':'wikitable sortable'})
table_body = table.find('tbody')
rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    if len(cols)>0:
        data.append([ele for ele in cols if ele])
df=pd.DataFrame(data)

df.columns=['PostCode','Borough','Neighborhood']
df.head()
df.shape
# Out:
# (289, 3)

# %% [markdown]
# ### Clean data to ignore 'Not assigned' Boroughs or Neighborhoods

# %%
df_tt=df[df['Borough'] != 'Not assigned'].reset_index(drop=True)
df_tt.head()
df_tt.shape
# Out:
# (212, 3)

# %%
for i, index in enumerate(df_tt.index.values):
    nerb = df_tt.loc[index, 'Neighborhood']

    if nerb == 'Not assigned':
        df_tt.loc[index,'Neighborhood'] = df_tt.loc[index,'Borough']
df_tt.shape
# Out:
# (212, 3)

# %% [markdown]
# ### Group Neighborhood by postcode and borough

# %%
g=df_tt.groupby(['PostCode', 'Borough'])
df_gp =g.apply( lambda x:','.join(x['Neighborhood'])).reset_index(name='Neighborhood')
df_gp.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Load Geograph data from csv file.

# %%
df_geo = pd.read_csv('http://cocl.us/Geospatial_data', index_col=0)
print('Geo data loaded')
# Out:
# Geo data loaded

# %% [markdown]
# ### Add the latitude and longitude data into neighborhood data

# %%
for index, row in df_gp.iterrows():
    pc = row['PostCode']
    df_gp.loc[index, 'Latitude'] = df_geo.loc[pc]['Latitude']
    df_gp.loc[index, 'Longitude'] = df_geo.loc[pc]['Longitude']

# %%
print('The dataframe has {} postcodes, {} boroughs and {} neighborhoods.'.format(
        len(df_gp['PostCode'].unique()),
        len(df_gp['Borough'].unique()),
        df_gp.shape[0]
    )
)
# Out:
# The dataframe has 103 postcodes, 11 boroughs and 103 neighborhoods.

# %%
toronto_data = df_gp

# %%
'''
toronto_data = df_gp[df_gp['Borough'].str.contains('Toronto') ].reset_index(drop=True)
print('The dataframe has {} postcodes, {} boroughs and {} neighborhoods which contains world Toronto in its Borough.'.format(
        len(toronto_data['PostCode'].unique()),
        len(toronto_data['Borough'].unique()),
        toronto_data.shape[0]
    )
)
'''
# Out:
# "\ntoronto_data = df_gp[df_gp['Borough'].str.contains('Toronto') ].reset_index(drop=True)\nprint('The dataframe has {} postcodes, {} boroughs and {} neighborhoods which contains world Toronto in its Borough.'.format(\n        len(toronto_data['PostCode'].unique()),\n        len(toronto_data['Borough'].unique()),\n        toronto_data.shape[0]\n    )\n)\n"

# %% [markdown]
# ### To visualize neighborhoods with folium map

# %%
address = 'Toronto, CA'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manhattan are 43.653963, -79.387207.

# %%
# create map of Manhattan using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
toronto_data.shape
# Out:
# (103, 5)

# %% [markdown]
# ### Use Foursqure API to get popular venues for each neighborhoods.

# %%
import requests

CLIENT_ID = 'RFIRBIWLR1J32AU5152LC5R0IEWENTABIYGZI5SZBZVYOA5S' # your Foursquare ID
CLIENT_SECRET = 'FQXBLNXERCFKIE53S3HZR4VVZYIO4RRMO2MWHRUS1G4GYJN0' # your Foursquare Secret
VERSION = '20181227' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

neighborhood_latitude = toronto_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = toronto_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = toronto_data.loc[1, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))

radius=500

LIMIT=100

url="https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
    CLIENT_ID,CLIENT_SECRET,VERSION,neighborhood_latitude,neighborhood_longitude,radius,LIMIT
)

results = requests.get(url).json()
# Out:
# Your credentails:
# CLIENT_ID: RFIRBIWLR1J32AU5152LC5R0IEWENTABIYGZI5SZBZVYOA5S
# CLIENT_SECRET:FQXBLNXERCFKIE53S3HZR4VVZYIO4RRMO2MWHRUS1G4GYJN0
# Latitude and longitude values of Highland Creek,Rouge Hill,Port Union are 43.806686299999996, -79.19435340000001.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# ### Fetch data from Foursqure API

# %%
from pandas.io.json import json_normalize

venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                     name            categories        lat        lng
# 0                Wendy's  Fast Food Restaurant  43.807448 -79.199056
# 1  Interprovincial Group            Print Shop  43.805630 -79.200378

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
    #    print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)
toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )

# %%
venue_list = toronto_venues['Venue Category'].tolist()

# %% [markdown]
# ### Select store and coffee shops from venue data for each neighborhood

# %%
s = set(venue_list)
venues = list(s)

stores_malls = []
coffee_shops = []
for l in venues:
    if l.find('Store') > -1 or l.find('Mall') > -1:
        stores_malls.append([l, 'Store'])
    elif l.find('Caf') > -1 or l.find('Coffee') > -1:
        coffee_shops.append([l, 'Coffee Shop'])
    else:
        continue
df_stores_malls = pd.DataFrame(stores_malls)
df_stores_malls.columns=['Venue Category', 'Type']
df_coffee_shops = pd.DataFrame(coffee_shops)
df_coffee_shops.columns=['Venue Category', 'Type']

# %%
df_v = df_stores_malls.append(other = df_coffee_shops, ignore_index=True)

# %% [markdown]
# ### Combine venue data with type of store and coffee shops

# %%
toronto_venues_flag = toronto_venues.join(df_v.set_index('Venue Category'), how = 'inner', on='Venue Category').reset_index(drop=True)
toronto_venues_flag.head()
# Out:
#                       Neighborhood  Neighborhood Latitude  \
# 0  Guildwood,Morningside,West Hill              43.763573
# 1       Fairview,Henry Farm,Oriole              43.778517
# 2                 Willowdale South              43.770120
# 3       CFB Toronto,Downsview East              43.737473
# 4                          Leaside              43.709060
#
#    Neighborhood Longitude                   Venue  Venue Latitude  \
# 0              -79.188711       G & G Electronics       43.765309
# 1              -79.346556          Apple Fairview       43.777952
# 2              -79.408493                Best Buy       43.768115
# 3              -79.464763  First Class Realty Ltd       43.737133
# 4              -79.363452                Best Buy       43.709255
#
#    Venue Longitude     Venue Category   Type
# 0       -79.191537  Electronics Store  Store
# 1       -79.343582  Electronics Store  Store
# 2       -79.412608  Electronics Store  Store
# 3       -79.463298  Electronics Store  Store
# 4       -79.361680  Electronics Store  Store

# %% [markdown]
# ### Add one hot dummies for type of stores/coffee shops.

# %%
toronto_venues_flag_onehot = pd.get_dummies(toronto_venues_flag[['Type']], prefix="", prefix_sep="")
toronto_venues_flag_onehot['Neighborhood'] = toronto_venues_flag['Neighborhood'] 
# move neighborhood column to the first column
fixed_columns = [toronto_venues_flag_onehot.columns[-1]] + list(toronto_venues_flag_onehot.columns[:-1])
toronto_venues_flag_onehot = toronto_venues_flag_onehot[fixed_columns]

t_cs= toronto_venues_flag_onehot.groupby(['Neighborhood'] ).sum()

# %% [markdown]
# ### Calculate two indicators: Rate and Diff for data analysis.

# %%
for index,row in t_cs.iterrows():
    v = row['Store']/row['Coffee Shop']
    t_cs.loc[index,'Rate'] = v
    t_cs.loc[index,'Diff'] = row['Store'] - row['Coffee Shop']
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:3: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()

# %%
t_cs.sort_values('Rate', ascending=False, inplace=True)
t_cs.reset_index()
# Out:
#                                          Neighborhood  Coffee Shop  Store  \
# 0                  Forest Hill North,Forest Hill West            0      1
# 1                                        East Toronto            0      1
# 2         Del Ray,Keelesdale,Mount Dennis,Silverthorn            0      1
# 3                                 Downsview Northwest            0      3
# 4                                 Caledonia-Fairbanks            0      1
# 5   Kingsway Park South West,Mimico NW,The Queensw...            0      3
# 6                          CFB Toronto,Downsview East            0      1
# 7               Clarks Corners,Sullivan,Tam O'Shanter            0      1
# 8                        The Junction North,Runnymede            0      2
# 9                                      Downsview West            0      2
# 10                      The Beaches West,India Bazaar            0      2
# 11                                   Woodbine Heights            0      1
# 12                                             Weston            0      1
# 13  Dorset Park,Scarborough Town Centre,Wexford He...            0      1
# 14                    Guildwood,Morningside,West Hill            0      1
# 15                    Lawrence Heights,Lawrence Manor            1      8
# 16                         Fairview,Henry Farm,Oriole            4     20
# 17                                   Thorncliffe Park            1      4
# 18                                            Leaside            3      9
# 19          East Birchmount Park,Ionview,Kennedy Park            1      3
# 20  Albion Gardens,Beaumond Heights,Humbergate,Jam...            1      3
# 21  Bloordale Gardens,Eringate,Markland Wood,Old B...            1      3
# 22                    Flemingdon Park,Don Mills South            2      4
# 23                        Dovercourt Village,Dufferin            1      2
# 24                       L'Amoreaux West,Steeles West            1      2
# 25                                   Willowdale South            4      6
# 26                                 North Toronto West            2      3
# 27                       High Park,The Junction South            2      3
# 28                        The Danforth West,Riverdale            4      5
# 29                                           Christie            4      5
# ..                                                ...          ...    ...
# 39                            Little Portugal,Trinity            6      4
# 40                                    Studio District            7      4
# 41                             Adelaide,King,Richmond           11      6
# 42                                        Berczy Park            6      3
# 43  Deer Park,Forest Hill SE,Rathnelly,South Hill,...            2      1
# 44            Chinatown,Grange Park,Kensington Market           13      6
# 45                           Harbourfront,Regent Park           11      4
# 46                      Harbord,University of Toronto            6      2
# 47         Humber Bay Shores,Mimico South,New Toronto            3      1
# 48                                         Davisville            4      1
# 49                    Stn A PO Boxes 25 The Esplanade           14      3
# 50                                 Central Bay Street           19      4
# 51                                       Queen's Park           11      2
# 52                  The Annex,North Midtown,Yorkville            6      1
# 53                      Commerce Court,Victoria Hotel           17      2
# 54              First Canadian Place,Underground city           16      1
# 55            Design Exchange,Toronto Dominion Centre           22      1
# 56                                   Victoria Village            1      0
# 57                                          Westmount            1      0
# 58                                             Woburn            2      0
# 59                              Alderwood,Long Branch            1      0
# 60                                  Runnymede,Swansea            7      0
# 61                                    Willowdale West            1      0
# 62                                    Bayview Village            1      0
# 63                         Birch Cliff,Cliffside West            1      0
# 64                                        The Beaches            1      0
# 65                              Parkdale,Roncesvalles            1      0
# 66                                    Don Mills North            1      0
# 67    Harbourfront East,Toronto Islands,Union Station           18      0
# 68              Canada Post Gateway Processing Centre            2      0
#
#         Rate  Diff
# 0        inf   1.0
# 1        inf   1.0
# 2        inf   1.0
# 3        inf   3.0
# 4        inf   1.0
# 5        inf   3.0
# 6        inf   1.0
# 7        inf   1.0
# 8        inf   2.0
# 9        inf   2.0
# 10       inf   2.0
# 11       inf   1.0
# 12       inf   1.0
# 13       inf   1.0
# 14       inf   1.0
# 15  8.000000   7.0
# 16  5.000000  16.0
# 17  4.000000   3.0
# 18  3.000000   6.0
# 19  3.000000   2.0
# 20  3.000000   2.0
# 21  3.000000   2.0
# 22  2.000000   2.0
# 23  2.000000   1.0
# 24  2.000000   1.0
# 25  1.500000   2.0
# 26  1.500000   1.0
# 27  1.500000   1.0
# 28  1.250000   1.0
# 29  1.250000   1.0
# ..       ...   ...
# 39  0.666667  -2.0
# 40  0.571429  -3.0
# 41  0.545455  -5.0
# 42  0.500000  -3.0
# 43  0.500000  -1.0
# 44  0.461538  -7.0
# 45  0.363636  -7.0
# 46  0.333333  -4.0
# 47  0.333333  -2.0
# 48  0.250000  -3.0
# 49  0.214286 -11.0
# 50  0.210526 -15.0
# 51  0.181818  -9.0
# 52  0.166667  -5.0
# 53  0.117647 -15.0
# 54  0.062500 -15.0
# 55  0.045455 -21.0
# 56  0.000000  -1.0
# 57  0.000000  -1.0
# 58  0.000000  -2.0
# 59  0.000000  -1.0
# 60  0.000000  -7.0
# 61  0.000000  -1.0
# 62  0.000000  -1.0
# 63  0.000000  -1.0
# 64  0.000000  -1.0
# 65  0.000000  -1.0
# 66  0.000000  -1.0
# 67  0.000000 -18.0
# 68  0.000000  -2.0
#
# [69 rows x 5 columns]

# %% [markdown]
# ### Combine neighborhood data with venue of stores and coffee shops data

# %%
toronto_merged = toronto_data.join(t_cs, how='right', on='Neighborhood', sort = False)
toronto_merged.sort_values('Rate', ascending=False, inplace=True)
toronto_merged.replace(np.inf, '10', inplace=True)
toronto_merged['Rate']= pd.to_numeric(toronto_merged['Rate'])

# %%
toronto_merged.reset_index(drop=True)
# Out:
#    PostCode           Borough  \
# 0       M1E       Scarborough
# 1       M6M              York
# 2       M3N        North York
# 3       M3L        North York
# 4       M3K        North York
# 5       M4J         East York
# 6       M4L      East Toronto
# 7       M5P   Central Toronto
# 8       M4C         East York
# 9       M6E              York
# 10      M6N              York
# 11      M8Z         Etobicoke
# 12      M1T       Scarborough
# 13      M1P       Scarborough
# 14      M9N              York
# 15      M6A        North York
# 16      M2J        North York
# 17      M4H         East York
# 18      M9C         Etobicoke
# 19      M4G         East York
# 20      M9V         Etobicoke
# 21      M1K       Scarborough
# 22      M3C        North York
# 23      M6H      West Toronto
# 24      M1W       Scarborough
# 25      M2N        North York
# 26      M6P      West Toronto
# 27      M4R   Central Toronto
# 28      M4K      East Toronto
# 29      M6G  Downtown Toronto
# ..      ...               ...
# 39      M6J      West Toronto
# 40      M4M      East Toronto
# 41      M5H  Downtown Toronto
# 42      M4V   Central Toronto
# 43      M5E  Downtown Toronto
# 44      M5T  Downtown Toronto
# 45      M5A  Downtown Toronto
# 46      M8V         Etobicoke
# 47      M5S  Downtown Toronto
# 48      M4S   Central Toronto
# 49      M5W  Downtown Toronto
# 50      M5G  Downtown Toronto
# 51      M7A      Queen's Park
# 52      M5R   Central Toronto
# 53      M5L  Downtown Toronto
# 54      M5X  Downtown Toronto
# 55      M5K  Downtown Toronto
# 56      M1G       Scarborough
# 57      M9P         Etobicoke
# 58      M4A        North York
# 59      M1N       Scarborough
# 60      M8W         Etobicoke
# 61      M6R      West Toronto
# 62      M7R       Mississauga
# 63      M6S      West Toronto
# 64      M3B        North York
# 65      M2K        North York
# 66      M5J  Downtown Toronto
# 67      M2R        North York
# 68      M4E      East Toronto
#
#                                          Neighborhood   Latitude  Longitude  \
# 0                     Guildwood,Morningside,West Hill  43.763573 -79.188711
# 1         Del Ray,Keelesdale,Mount Dennis,Silverthorn  43.691116 -79.476013
# 2                                 Downsview Northwest  43.761631 -79.520999
# 3                                      Downsview West  43.739015 -79.506944
# 4                          CFB Toronto,Downsview East  43.737473 -79.464763
# 5                                        East Toronto  43.685347 -79.338106
# 6                       The Beaches West,India Bazaar  43.668999 -79.315572
# 7                  Forest Hill North,Forest Hill West  43.696948 -79.411307
# 8                                    Woodbine Heights  43.695344 -79.318389
# 9                                 Caledonia-Fairbanks  43.689026 -79.453512
# 10                       The Junction North,Runnymede  43.673185 -79.487262
# 11  Kingsway Park South West,Mimico NW,The Queensw...  43.628841 -79.520999
# 12              Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 13  Dorset Park,Scarborough Town Centre,Wexford He...  43.757410 -79.273304
# 14                                             Weston  43.706876 -79.518188
# 15                    Lawrence Heights,Lawrence Manor  43.718518 -79.464763
# 16                         Fairview,Henry Farm,Oriole  43.778517 -79.346556
# 17                                   Thorncliffe Park  43.705369 -79.349372
# 18  Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 19                                            Leaside  43.709060 -79.363452
# 20  Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.739416 -79.588437
# 21          East Birchmount Park,Ionview,Kennedy Park  43.727929 -79.262029
# 22                    Flemingdon Park,Don Mills South  43.725900 -79.340923
# 23                        Dovercourt Village,Dufferin  43.669005 -79.442259
# 24                       L'Amoreaux West,Steeles West  43.799525 -79.318389
# 25                                   Willowdale South  43.770120 -79.408493
# 26                       High Park,The Junction South  43.661608 -79.464763
# 27                                 North Toronto West  43.715383 -79.405678
# 28                        The Danforth West,Riverdale  43.679557 -79.352188
# 29                                           Christie  43.669542 -79.422564
# ..                                                ...        ...        ...
# 39                            Little Portugal,Trinity  43.647927 -79.419750
# 40                                    Studio District  43.659526 -79.340923
# 41                             Adelaide,King,Richmond  43.650571 -79.384568
# 42  Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.686412 -79.400049
# 43                                        Berczy Park  43.644771 -79.373306
# 44            Chinatown,Grange Park,Kensington Market  43.653206 -79.400049
# 45                           Harbourfront,Regent Park  43.654260 -79.360636
# 46         Humber Bay Shores,Mimico South,New Toronto  43.605647 -79.501321
# 47                      Harbord,University of Toronto  43.662696 -79.400049
# 48                                         Davisville  43.704324 -79.388790
# 49                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 50                                 Central Bay Street  43.657952 -79.387383
# 51                                       Queen's Park  43.662301 -79.389494
# 52                  The Annex,North Midtown,Yorkville  43.672710 -79.405678
# 53                      Commerce Court,Victoria Hotel  43.648198 -79.379817
# 54              First Canadian Place,Underground city  43.648429 -79.382280
# 55            Design Exchange,Toronto Dominion Centre  43.647177 -79.381576
# 56                                             Woburn  43.770992 -79.216917
# 57                                          Westmount  43.696319 -79.532242
# 58                                   Victoria Village  43.725882 -79.315572
# 59                         Birch Cliff,Cliffside West  43.692657 -79.264848
# 60                              Alderwood,Long Branch  43.602414 -79.543484
# 61                              Parkdale,Roncesvalles  43.648960 -79.456325
# 62              Canada Post Gateway Processing Centre  43.636966 -79.615819
# 63                                  Runnymede,Swansea  43.651571 -79.484450
# 64                                    Don Mills North  43.745906 -79.352188
# 65                                    Bayview Village  43.786947 -79.385975
# 66    Harbourfront East,Toronto Islands,Union Station  43.640816 -79.381752
# 67                                    Willowdale West  43.782736 -79.442259
# 68                                        The Beaches  43.676357 -79.293031
#
#     Coffee Shop  Store       Rate  Diff
# 0             0      1  10.000000   1.0
# 1             0      1  10.000000   1.0
# 2             0      3  10.000000   3.0
# 3             0      2  10.000000   2.0
# 4             0      1  10.000000   1.0
# 5             0      1  10.000000   1.0
# 6             0      2  10.000000   2.0
# 7             0      1  10.000000   1.0
# 8             0      1  10.000000   1.0
# 9             0      1  10.000000   1.0
# 10            0      2  10.000000   2.0
# 11            0      3  10.000000   3.0
# 12            0      1  10.000000   1.0
# 13            0      1  10.000000   1.0
# 14            0      1  10.000000   1.0
# 15            1      8   8.000000   7.0
# 16            4     20   5.000000  16.0
# 17            1      4   4.000000   3.0
# 18            1      3   3.000000   2.0
# 19            3      9   3.000000   6.0
# 20            1      3   3.000000   2.0
# 21            1      3   3.000000   2.0
# 22            2      4   2.000000   2.0
# 23            1      2   2.000000   1.0
# 24            1      2   2.000000   1.0
# 25            4      6   1.500000   2.0
# 26            2      3   1.500000   1.0
# 27            2      3   1.500000   1.0
# 28            4      5   1.250000   1.0
# 29            4      5   1.250000   1.0
# ..          ...    ...        ...   ...
# 39            6      4   0.666667  -2.0
# 40            7      4   0.571429  -3.0
# 41           11      6   0.545455  -5.0
# 42            2      1   0.500000  -1.0
# 43            6      3   0.500000  -3.0
# 44           13      6   0.461538  -7.0
# 45           11      4   0.363636  -7.0
# 46            3      1   0.333333  -2.0
# 47            6      2   0.333333  -4.0
# 48            4      1   0.250000  -3.0
# 49           14      3   0.214286 -11.0
# 50           19      4   0.210526 -15.0
# 51           11      2   0.181818  -9.0
# 52            6      1   0.166667  -5.0
# 53           17      2   0.117647 -15.0
# 54           16      1   0.062500 -15.0
# 55           22      1   0.045455 -21.0
# 56            2      0   0.000000  -2.0
# 57            1      0   0.000000  -1.0
# 58            1      0   0.000000  -1.0
# 59            1      0   0.000000  -1.0
# 60            1      0   0.000000  -1.0
# 61            1      0   0.000000  -1.0
# 62            2      0   0.000000  -2.0
# 63            7      0   0.000000  -7.0
# 64            1      0   0.000000  -1.0
# 65            1      0   0.000000  -1.0
# 66           18      0   0.000000 -18.0
# 67            1      0   0.000000  -1.0
# 68            1      0   0.000000  -1.0
#
# [69 rows x 9 columns]

# %% [markdown]
# ### Visualize the neighborhood with marking selected high business potential with red and bigger markers.

# %%
# create map of Manhattan using latitude and longitude values
map_toronto_merged = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label, c, s, r, d in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], 
                                 toronto_merged['Coffee Shop'], toronto_merged['Store'], 
                                       toronto_merged['Rate'], toronto_merged['Diff']):
    label = folium.Popup(label, parse_html=True)
    co = 'blue'
    ra = 1
    if r >= 1 and d >=3:
        co = 'Red'
        ra = d
    folium.CircleMarker(
        [lat, lng],
        radius=ra,
        popup=label,
        color=co,
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto_merged)  
    
map_toronto_merged
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
